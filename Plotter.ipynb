# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %pylab inline
pylab.rcParams['figure.figsize']=(12,8)
#%matplotlib notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('2900128278.csv', delimiter=';', index_col='recorded', parse_dates=True)
data.head()
# Out:
#                      radonShortTermAvg (pCi/L)  humidity (%)  temp (°F)
# recorded
# 2018-09-19 17:06:32                        0.0          39.0       75.0
# 2018-09-19 18:06:32                        0.0          38.5       75.0
# 2018-09-19 19:06:32                        0.0          39.5       75.0
# 2018-09-19 20:06:32                        0.0          38.5       76.0
# 2018-09-19 22:05:11                        0.0          38.0       83.0

# %%
data.describe()
# Out:
#        radonShortTermAvg (pCi/L)  humidity (%)    temp (°F)
# count                2555.000000   2555.000000  2555.000000
# mean                    3.269393     34.203718    63.218787
# std                     1.964531      5.920338     6.057758
# min                     0.000000     21.500000    48.000000
# 25%                     1.600000     29.500000    59.000000
# 50%                     3.000000     33.500000    62.000000
# 75%                     4.600000     38.500000    66.000000
# max                     9.400000     51.000000    84.000000

# %%
fig,ax = plt.subplots()
ax.plot(data.index, data['radonShortTermAvg (pCi/L)'])
ax.set_ylabel("Radon Short Term Average (pCi/L)")

# %%
fig,ax = plt.subplots()
ax.plot(data.index, data['radonShortTermAvg (pCi/L)'])
ax.set_ylabel("Radon Short Term Average (pCi/L)")
ax.set_title("Hourly Radon Sampling October 2018")
ax.set_xlim([datetime.date(2018, 10, 1), datetime.date(2018, 11, 1)])
ax.set_ylim(0, 9)
# Out:
# (0, 9)

# %%
fig,ax = plt.subplots()
ax.plot(data.index, data['radonShortTermAvg (pCi/L)'])
ax.set_ylabel("Radon Short Term Average (pCi/L)")
ax.set_title("Hourly Radon Sampling December 2018")
ax.set_xlim([datetime.date(2018, 12, 1), datetime.date(2019, 1, 1)])
ax.set_ylim(0, 9)
# Out:
# (0, 9)
